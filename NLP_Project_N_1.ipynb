# %% [markdown]
# <a href="https://colab.research.google.com/github/JamshidbekYusupov/Mohirdev_Tutorial_Codes/blob/main/NLP_Project_N_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import fastai

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from fastai.text.all import *

path = untar_data(URLs.IMDB)

path.ls()
# Out:
# (#7) [Path('/root/.fastai/data/imdb/unsup'),Path('/root/.fastai/data/imdb/train'),Path('/root/.fastai/data/imdb/tmp_clas'),Path('/root/.fastai/data/imdb/README'),Path('/root/.fastai/data/imdb/tmp_lm'),Path('/root/.fastai/data/imdb/test'),Path('/root/.fastai/data/imdb/imdb.vocab')]

# %%
##DataLoaders.

dls = TextDataLoaders.from_folder(path, train='train', valid='test')

learn = text_classifier_learner(dls, AWD_LSTM, drop_mult=0.5, metrics = accuracy)

learn.fine_tune(4, 0.01)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
learn.predict('worst')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('pos', tensor(1), tensor([0.0638, 0.9362]))

# %%
dls.vocab
# Out:
# (#2) [['xxunk', 'xxpad', 'xxbos', 'xxeos', 'xxfld', 'xxrep', 'xxwrep', 'xxup', 'xxmaj', 'the', '.', ',', 'and', 'a', 'of', 'to', 'is', 'it', 'in', 'i', 'this', 'that', '"', "'s", '-', 'was', '\n\n', 'as', 'with', 'for', 'movie', 'but', 'film', 'you', ')', 'on', "n't", '(', 'not', 'are', 'he', 'his', 'have', 'be', 'one', 'all', 'at', 'they', 'by', 'an', 'who', 'from', 'so', 'like', '!', 'there', 'or', 'just', 'her', 'do', 'about', 'out', 'has', 'if', "'", 'what', 'some', '?', 'good', 'when', 'more', 'very', 'she', 'up', 'would', 'no', '…', 'time', 'even', 'my', 'can', 'their', 'which', 'only', 'story', 'really', 'see', 'had', 'were', 'did', 'me', 'well', 'we', 'does', 'than', 'much', 'could', 'bad', 'get', 'been', ':', 'people', 'other', 'great', 'into', 'also', 'will', 'first', 'because', 'him', 'how', 'most', 'them', 'made', 'make', 'its', 'then', 'way', 'too', 'movies', 'after', 'any', 'characters', 'think', 'character', '/', 'films', 'watch', 'two', 'being', 'many', 'plot', 'seen'
# ...

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
print(len(dls.train_ds))
print(len(dls.valid_ds))
# Out:
# 25000
# 25000

# %%
Counter(dls.train_ds.items)
# Out:
# Counter({Path('/root/.fastai/data/imdb/train/pos/7309_9.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/6526_7.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/10530_10.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/6678_7.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/6312_7.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/6993_7.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/9223_9.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/6594_10.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/5009_9.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/2121_10.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/5956_9.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/1478_7.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/4067_8.txt'): 1,
#          Path('/root/.fastai/data/imdb/train/pos/196_9.txt'): 1,
# ...

# %%
print(dls.vocab)
# Out:
# [['xxunk', 'xxpad', 'xxbos', 'xxeos', 'xxfld', 'xxrep', 'xxwrep', 'xxup', 'xxmaj', 'the', '.', ',', 'and', 'a', 'of', 'to', 'is', 'it', 'in', 'i', 'this', 'that', '"', "'s", '-', 'was', '\n\n', 'as', 'with', 'for', 'movie', 'but', 'film', 'you', ')', 'on', "n't", '(', 'not', 'are', 'he', 'his', 'have', 'be', 'one', 'all', 'at', 'they', 'by', 'an', 'who', 'from', 'so', 'like', '!', 'there', 'or', 'just', 'her', 'do', 'about', 'out', 'has', 'if', "'", 'what', 'some', '?', 'good', 'when', 'more', 'very', 'she', 'up', 'would', 'no', '…', 'time', 'even', 'my', 'can', 'their', 'which', 'only', 'story', 'really', 'see', 'had', 'were', 'did', 'me', 'well', 'we', 'does', 'than', 'much', 'could', 'bad', 'get', 'been', ':', 'people', 'other', 'great', 'into', 'also', 'will', 'first', 'because', 'him', 'how', 'most', 'them', 'made', 'make', 'its', 'then', 'way', 'too', 'movies', 'after', 'any', 'characters', 'think', 'character', '/', 'films', 'watch', 'two', 'being', 'many', 'plot', 'seen', 'ne
# ...

# %%
learn.predict('negative')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('pos', tensor(1), tensor([0.0365, 0.9635]))
